# %%
import cv2
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
def displayImage(img):
    matImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(matImg)

# %%
img=cv2.imread("all-images/im0001.ppm",1)
displayImage(img)
# Out:
# <img src="data:image/png;base64,..." width="640">
